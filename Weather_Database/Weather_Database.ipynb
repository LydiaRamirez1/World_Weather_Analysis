# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit
import json
# Import the requests library.
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=51961f3e0f128672f8faf799c708fa35

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_description = city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | bolgar
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | skjervoy
# Processing Record 7 of Set 1 | huarmey
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | jinchang
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | touros
# Processing Record 12 of Set 1 | kalmunai
# Processing Record 13 of Set 1 | garowe
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | anadyr
# Processing Record 16 of Set 1 | kudahuvadhoo
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | half moon bay
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | sembe
# Processing Record 21 of Set 1 | juquia
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | mumford
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | pangai
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | aripuana
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | evensk
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | gromiljak
# Processing Record 39 of Set 1 | praia da vitoria
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 1 | miri
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 1 | tadine
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | merauke
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | iskateley
# Processing Record 1 of Set 2 | mayo
# Processing Record 2 of Set 2 | nalut
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | kushmurun
# Processing Record 6 of Set 2 | aleksandrov gay
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | thiruvananthapuram
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | mecca
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | sechura
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | taywarah
# Processing Record 20 of Set 2 | asau
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | shu
# Processing Record 24 of Set 2 | champerico
# Processing Record 25 of Set 2 | kabalo
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | kamenka
# Processing Record 28 of Set 2 | broome
# Processing Record 29 of Set 2 | pucallpa
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | palembang
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | ketchikan
# Processing Record 34 of Set 2 | acarau
# Processing Record 35 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | wewak
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | sungay
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint-pierre
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | itarema
# Processing Record 45 of Set 2 | fairbanks
# Processing Record 46 of Set 2 | mugur-aksy
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | panorama
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | sitka
# Processing Record 1 of Set 3 | la asuncion
# Processing Record 2 of Set 3 | sabya
# Processing Record 3 of Set 3 | rock springs
# Processing Record 4 of Set 3 | bandarbeyla
# Processing Record 5 of Set 3 | lakatoro
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | kampot
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | dafeng
# Processing Record 11 of Set 3 | suruc
# Processing Record 12 of Set 3 | baijiantan
# Processing Record 13 of Set 3 | turinsk
# Processing Record 14 of Set 3 | taoudenni
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | teluk nibung
# Processing Record 19 of Set 3 | arlit
# Processing Record 20 of Set 3 | yangambi
# Processing Record 21 of Set 3 | tripoli
# Processing Record 22 of Set 3 | pontianak
# Processing Record 23 of Set 3 | buzmeyin
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | tehachapi
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | dmitriyevskoye
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | najran
# Processing Record 32 of Set 3 | olinda
# Processing Record 33 of Set 3 | contamana
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | kazanovka
# City not found. Skipping...
# Processing Record 37 of Set 3 | ashland
# Processing Record 38 of Set 3 | watsa
# Processing Record 39 of Set 3 | cah ab
# City not found. Skipping...
# Processing Record 40 of Set 3 | kondagaon
# Processing Record 41 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 42 of Set 3 | viedma
# Processing Record 43 of Set 3 | plettenberg bay
# Processing Record 44 of Set 3 | ertil
# Processing Record 45 of Set 3 | jonuta
# Processing Record 46 of Set 3 | santa cruz cabralia
# Processing Record 47 of Set 3 | thonon-les-bains
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | mount gambier
# Processing Record 50 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 1 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | cidreira
# Processing Record 4 of Set 4 | aksarka
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | riyadh
# Processing Record 7 of Set 4 | pacific grove
# Processing Record 8 of Set 4 | hualmay
# Processing Record 9 of Set 4 | tucuman
# Processing Record 10 of Set 4 | vila
# Processing Record 11 of Set 4 | bengkulu
# Processing Record 12 of Set 4 | ocampo
# Processing Record 13 of Set 4 | synya
# Processing Record 14 of Set 4 | shakawe
# Processing Record 15 of Set 4 | yerofey pavlovich
# Processing Record 16 of Set 4 | antalaha
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | colares
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | seduva
# Processing Record 23 of Set 4 | oro valley
# Processing Record 24 of Set 4 | corrales
# Processing Record 25 of Set 4 | homer
# Processing Record 26 of Set 4 | gat
# Processing Record 27 of Set 4 | diu
# Processing Record 28 of Set 4 | miracema do tocantins
# Processing Record 29 of Set 4 | ngama
# Processing Record 30 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 4 | college
# Processing Record 32 of Set 4 | zilair
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | khingansk
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | san luis
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | linjiang
# Processing Record 39 of Set 4 | meiganga
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | ahipara
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 4 | omsukchan
# Processing Record 45 of Set 4 | whitecourt
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | muros
# Processing Record 48 of Set 4 | kijang
# Processing Record 49 of Set 4 | derzhavinsk
# Processing Record 50 of Set 4 | port lincoln
# Processing Record 1 of Set 5 | usak
# Processing Record 2 of Set 5 | sao joao da barra
# Processing Record 3 of Set 5 | gumdag
# Processing Record 4 of Set 5 | oriximina
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | bizhbulyak
# Processing Record 9 of Set 5 | morgan city
# Processing Record 10 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | kirovskiy
# Processing Record 13 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | sinj
# Processing Record 16 of Set 5 | pemangkat
# Processing Record 17 of Set 5 | belmonte
# Processing Record 18 of Set 5 | gaspe
# Processing Record 19 of Set 5 | port angeles
# Processing Record 20 of Set 5 | marawi
# Processing Record 21 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 5 | sampit
# Processing Record 23 of Set 5 | udachnyy
# Processing Record 24 of Set 5 | orlik
# Processing Record 25 of Set 5 | san andres
# Processing Record 26 of Set 5 | hay river
# Processing Record 27 of Set 5 | bakal
# Processing Record 28 of Set 5 | pahrump
# Processing Record 29 of Set 5 | urengoy
# Processing Record 30 of Set 5 | moindou
# Processing Record 31 of Set 5 | ucluelet
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | calatayud
# Processing Record 34 of Set 5 | batticaloa
# Processing Record 35 of Set 5 | stornoway
# Processing Record 36 of Set 5 | ushtobe
# Processing Record 37 of Set 5 | pundaguitan
# Processing Record 38 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 39 of Set 5 | swan river
# Processing Record 40 of Set 5 | dhidhdhoo
# Processing Record 41 of Set 5 | umba
# Processing Record 42 of Set 5 | yellowknife
# Processing Record 43 of Set 5 | hithadhoo
# Processing Record 44 of Set 5 | port macquarie
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | bradeanu
# Processing Record 48 of Set 5 | piranshahr
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | road town
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | new norfolk
# Processing Record 3 of Set 6 | sorland
# Processing Record 4 of Set 6 | uvinza
# Processing Record 5 of Set 6 | berlevag
# Processing Record 6 of Set 6 | tomarovka
# Processing Record 7 of Set 6 | lorengau
# Processing Record 8 of Set 6 | bilibino
# City not found. Skipping...
# Processing Record 9 of Set 6 | jining
# Processing Record 10 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | hovd
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | sinop
# Processing Record 17 of Set 6 | baoning
# Processing Record 18 of Set 6 | moroni
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | mopipi
# Processing Record 21 of Set 6 | charters towers
# Processing Record 22 of Set 6 | mattawa
# Processing Record 23 of Set 6 | caloundra
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | kutum
# Processing Record 26 of Set 6 | chernaya kholunitsa
# Processing Record 27 of Set 6 | anaco
# Processing Record 28 of Set 6 | teya
# Processing Record 29 of Set 6 | porto novo
# Processing Record 30 of Set 6 | irbil
# Processing Record 31 of Set 6 | maniitsoq
# Processing Record 32 of Set 6 | orocue
# Processing Record 33 of Set 6 | haines junction
# Processing Record 34 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | vzmorye
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 39 of Set 6 | newton
# Processing Record 40 of Set 6 | axim
# Processing Record 41 of Set 6 | seydi
# Processing Record 42 of Set 6 | mutare
# Processing Record 43 of Set 6 | loudeac
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | arraial do cabo
# Processing Record 46 of Set 6 | isla mujeres
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 6 | gizo
# Processing Record 1 of Set 7 | correntina
# Processing Record 2 of Set 7 | acapulco
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | norman wells
# Processing Record 5 of Set 7 | padang
# Processing Record 6 of Set 7 | airai
# Processing Record 7 of Set 7 | roald
# Processing Record 8 of Set 7 | thunder bay
# Processing Record 9 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 7 | victor harbor
# Processing Record 11 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | columbus
# Processing Record 13 of Set 7 | saint combs
# City not found. Skipping...
# Processing Record 14 of Set 7 | ende
# Processing Record 15 of Set 7 | coihaique
# Processing Record 16 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 17 of Set 7 | catamarca
# Processing Record 18 of Set 7 | yurla
# Processing Record 19 of Set 7 | naryan-mar
# Processing Record 20 of Set 7 | lampang
# Processing Record 21 of Set 7 | phan thiet
# Processing Record 22 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | lichuan
# Processing Record 25 of Set 7 | liverpool
# Processing Record 26 of Set 7 | moron
# Processing Record 27 of Set 7 | jacqueville
# Processing Record 28 of Set 7 | buraydah
# Processing Record 29 of Set 7 | keighley
# Processing Record 30 of Set 7 | chuy
# Processing Record 31 of Set 7 | mandali
# Processing Record 32 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 7 | berbera
# Processing Record 34 of Set 7 | port hawkesbury
# Processing Record 35 of Set 7 | mount pleasant
# Processing Record 36 of Set 7 | kedrovyy
# Processing Record 37 of Set 7 | soe
# Processing Record 38 of Set 7 | cururupu
# Processing Record 39 of Set 7 | tucuma
# Processing Record 40 of Set 7 | edgewater
# Processing Record 41 of Set 7 | saint-philippe
# Processing Record 42 of Set 7 | contai
# Processing Record 43 of Set 7 | emerald
# Processing Record 44 of Set 7 | tukrah
# Processing Record 45 of Set 7 | kangaatsiaq
# Processing Record 46 of Set 7 | atherton
# Processing Record 47 of Set 7 | westport
# Processing Record 48 of Set 7 | lesnoy
# Processing Record 49 of Set 7 | iqaluit
# Processing Record 50 of Set 7 | talnakh
# Processing Record 1 of Set 8 | sao jose de piranhas
# Processing Record 2 of Set 8 | ponta delgada
# Processing Record 3 of Set 8 | comodoro rivadavia
# Processing Record 4 of Set 8 | ellisras
# Processing Record 5 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 8 | chicama
# Processing Record 7 of Set 8 | santarem
# Processing Record 8 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 8 | jacareacanga
# Processing Record 10 of Set 8 | podgornoye
# Processing Record 11 of Set 8 | puri
# Processing Record 12 of Set 8 | gombong
# Processing Record 13 of Set 8 | mackenzie
# Processing Record 14 of Set 8 | morant bay
# Processing Record 15 of Set 8 | fort-shevchenko
# Processing Record 16 of Set 8 | puerto escondido
# Processing Record 17 of Set 8 | rio grande
# Processing Record 18 of Set 8 | ponta do sol
# Processing Record 19 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 20 of Set 8 | mikhaylovka
# Processing Record 21 of Set 8 | koroni
# Processing Record 22 of Set 8 | havre-saint-pierre
# Processing Record 23 of Set 8 | bathsheba
# Processing Record 24 of Set 8 | pushchino
# Processing Record 25 of Set 8 | careiro da varzea
# Processing Record 26 of Set 8 | east london
# Processing Record 27 of Set 8 | zhanjiang
# Processing Record 28 of Set 8 | emporia
# Processing Record 29 of Set 8 | mtwara
# Processing Record 30 of Set 8 | rolla
# Processing Record 31 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 32 of Set 8 | altay
# Processing Record 33 of Set 8 | vardo
# Processing Record 34 of Set 8 | cairns
# Processing Record 35 of Set 8 | primorsk
# Processing Record 36 of Set 8 | bereda
# Processing Record 37 of Set 8 | semey
# Processing Record 38 of Set 8 | abalak
# Processing Record 39 of Set 8 | meulaboh
# Processing Record 40 of Set 8 | santiago
# Processing Record 41 of Set 8 | lokosovo
# Processing Record 42 of Set 8 | sabha
# Processing Record 43 of Set 8 | svetlogorsk
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | taksimo
# Processing Record 47 of Set 8 | xining
# Processing Record 48 of Set 8 | atar
# Processing Record 49 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 8 | zhigansk
# Processing Record 1 of Set 9 | ovalle
# Processing Record 2 of Set 9 | thibodaux
# Processing Record 3 of Set 9 | waingapu
# Processing Record 4 of Set 9 | oranjestad
# Processing Record 5 of Set 9 | khatanga
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | barao de melgaco
# Processing Record 8 of Set 9 | wanning
# Processing Record 9 of Set 9 | sistranda
# Processing Record 10 of Set 9 | hervey bay
# Processing Record 11 of Set 9 | cabo san lucas
# Processing Record 12 of Set 9 | loubomo
# Processing Record 13 of Set 9 | chengam
# Processing Record 14 of Set 9 | chimbote
# Processing Record 15 of Set 9 | naze
# Processing Record 16 of Set 9 | sambava
# Processing Record 17 of Set 9 | sola
# Processing Record 18 of Set 9 | batagay-alyta
# Processing Record 19 of Set 9 | lazaro cardenas
# Processing Record 20 of Set 9 | ballina
# Processing Record 21 of Set 9 | pimentel
# Processing Record 22 of Set 9 | cordoba
# Processing Record 23 of Set 9 | chifeng
# Processing Record 24 of Set 9 | solnechnyy
# Processing Record 25 of Set 9 | yuli
# Processing Record 26 of Set 9 | cabedelo
# Processing Record 27 of Set 9 | odweyne
# Processing Record 28 of Set 9 | hambantota
# Processing Record 29 of Set 9 | marabba
# Processing Record 30 of Set 9 | popondetta
# Processing Record 31 of Set 9 | aktash
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | uberaba
# Processing Record 34 of Set 9 | kahului
# Processing Record 35 of Set 9 | juegang
# Processing Record 36 of Set 9 | sanmenxia
# Processing Record 37 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | boralday
# Processing Record 40 of Set 9 | bahia blanca
# Processing Record 41 of Set 9 | boone
# Processing Record 42 of Set 9 | kununurra
# Processing Record 43 of Set 9 | angoche
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | lasa
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | concepcion batres
# Processing Record 48 of Set 9 | orizona
# Processing Record 49 of Set 9 | constitucion
# Processing Record 50 of Set 9 | sao gabriel da cachoeira
# Processing Record 1 of Set 10 | nieuw amsterdam
# Processing Record 2 of Set 10 | donskoye
# Processing Record 3 of Set 10 | eidsvag
# Processing Record 4 of Set 10 | vestmannaeyjar
# Processing Record 5 of Set 10 | tuatapere
# Processing Record 6 of Set 10 | alekseyevka
# Processing Record 7 of Set 10 | owensboro
# Processing Record 8 of Set 10 | husavik
# Processing Record 9 of Set 10 | griffith
# Processing Record 10 of Set 10 | manzanillo
# Processing Record 11 of Set 10 | santa maria del oro
# Processing Record 12 of Set 10 | cabinda
# Processing Record 13 of Set 10 | te anau
# Processing Record 14 of Set 10 | mayumba
# Processing Record 15 of Set 10 | callaway
# Processing Record 16 of Set 10 | mae sai
# Processing Record 17 of Set 10 | lethem
# Processing Record 18 of Set 10 | nueva loja
# Processing Record 19 of Set 10 | north battleford
# Processing Record 20 of Set 10 | malaya purga
# Processing Record 21 of Set 10 | eidfjord
# Processing Record 22 of Set 10 | palu
# Processing Record 23 of Set 10 | sibolga
# Processing Record 24 of Set 10 | santa maria
# Processing Record 25 of Set 10 | marana
# Processing Record 26 of Set 10 | camalu
# Processing Record 27 of Set 10 | nuuk
# Processing Record 28 of Set 10 | byron bay
# Processing Record 29 of Set 10 | velyka bahachka
# Processing Record 30 of Set 10 | olafsvik
# Processing Record 31 of Set 10 | kismayo
# Processing Record 32 of Set 10 | yulara
# Processing Record 33 of Set 10 | sorong
# Processing Record 34 of Set 10 | bonavista
# Processing Record 35 of Set 10 | bagdarin
# Processing Record 36 of Set 10 | iturama
# Processing Record 37 of Set 10 | san antonio
# Processing Record 38 of Set 10 | antioch
# Processing Record 39 of Set 10 | dingle
# Processing Record 40 of Set 10 | fuerte olimpo
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | radhanpur
# Processing Record 43 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 10 | pisco
# Processing Record 45 of Set 10 | narsaq
# Processing Record 46 of Set 10 | shingu
# Processing Record 47 of Set 10 | syamzha
# Processing Record 48 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 10 | tabou
# Processing Record 50 of Set 10 | hobyo
# Processing Record 1 of Set 11 | mount isa
# Processing Record 2 of Set 11 | owando
# Processing Record 3 of Set 11 | skibbereen
# Processing Record 4 of Set 11 | yumen
# Processing Record 5 of Set 11 | kuytun
# Processing Record 6 of Set 11 | ambon
# Processing Record 7 of Set 11 | warri
# Processing Record 8 of Set 11 | maraa
# Processing Record 9 of Set 11 | alihe
# Processing Record 10 of Set 11 | oussouye
# Processing Record 11 of Set 11 | kilimatinde
# Processing Record 12 of Set 11 | qasigiannguit
# Processing Record 13 of Set 11 | taranagar
# Processing Record 14 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 11 | kavaratti
# Processing Record 16 of Set 11 | southbridge
# Processing Record 17 of Set 11 | almaznyy
# Processing Record 18 of Set 11 | vila franca do campo
# Processing Record 19 of Set 11 | nchelenge
# Processing Record 20 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 11 | ayna
# Processing Record 22 of Set 11 | dawei
# Processing Record 23 of Set 11 | behbahan
# Processing Record 24 of Set 11 | noumea
# Processing Record 25 of Set 11 | jamame
# Processing Record 26 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 11 | medvode
# Processing Record 28 of Set 11 | shipunovo
# Processing Record 29 of Set 11 | oxelosund
# Processing Record 30 of Set 11 | grand gaube
# Processing Record 31 of Set 11 | klyuchi
# Processing Record 32 of Set 11 | egvekinot
# Processing Record 33 of Set 11 | christchurch
# Processing Record 34 of Set 11 | tucano
# Processing Record 35 of Set 11 | babushkin
# Processing Record 36 of Set 11 | siddipet
# Processing Record 37 of Set 11 | roma
# Processing Record 38 of Set 11 | manggar
# Processing Record 39 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 11 | hue
# Processing Record 41 of Set 11 | adiake
# Processing Record 42 of Set 11 | sioux lookout
# Processing Record 43 of Set 11 | krasnoye
# Processing Record 44 of Set 11 | port moresby
# Processing Record 45 of Set 11 | gorontalo
# Processing Record 46 of Set 11 | eureka
# Processing Record 47 of Set 11 | nhulunbuy
# Processing Record 48 of Set 11 | bac lieu
# Processing Record 49 of Set 11 | seoul
# Processing Record 50 of Set 11 | swan hill
# Processing Record 1 of Set 12 | verkh-usugli
# Processing Record 2 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 12 | dubbo
# Processing Record 4 of Set 12 | codrington
# Processing Record 5 of Set 12 | alekseyevskaya
# Processing Record 6 of Set 12 | concarneau
# Processing Record 7 of Set 12 | twentynine palms
# Processing Record 8 of Set 12 | weiser
# Processing Record 9 of Set 12 | san jose
# Processing Record 10 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 12 | razole
# Processing Record 12 of Set 12 | buin
# Processing Record 13 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 14 of Set 12 | colon
# Processing Record 15 of Set 12 | alma
# Processing Record 16 of Set 12 | tahe
# Processing Record 17 of Set 12 | ecoporanga
# Processing Record 18 of Set 12 | manacapuru
# Processing Record 19 of Set 12 | kampong cham
# Processing Record 20 of Set 12 | kalmar
# Processing Record 21 of Set 12 | peniche
# Processing Record 22 of Set 12 | muslyumovo
# Processing Record 23 of Set 12 | portland
# Processing Record 24 of Set 12 | montepuez
# Processing Record 25 of Set 12 | paracuru
# Processing Record 26 of Set 12 | nome
# Processing Record 27 of Set 12 | diffa
# Processing Record 28 of Set 12 | necochea
# Processing Record 29 of Set 12 | pedra branca
# Processing Record 30 of Set 12 | los llanos de aridane
# Processing Record 31 of Set 12 | pangody
# Processing Record 32 of Set 12 | valparaiso
# Processing Record 33 of Set 12 | kirakira
# Processing Record 34 of Set 12 | grafton
# Processing Record 35 of Set 12 | kloulklubed
# Processing Record 36 of Set 12 | mantua
# Processing Record 37 of Set 12 | cap malheureux
# Processing Record 38 of Set 12 | fort saint james
# Processing Record 39 of Set 12 | beloha
# Processing Record 40 of Set 12 | ayan
# Processing Record 41 of Set 12 | umm lajj
# Processing Record 42 of Set 12 | pingdingshan
# Processing Record 43 of Set 12 | whitehorse
# Processing Record 44 of Set 12 | pleshanovo
# Processing Record 45 of Set 12 | kenai
# Processing Record 46 of Set 12 | shiozawa
# Processing Record 47 of Set 12 | shubarshi
# Processing Record 48 of Set 12 | walvis bay
# Processing Record 49 of Set 12 | artyom
# Processing Record 50 of Set 12 | bairiki
# Processing Record 1 of Set 13 | hastings
# Processing Record 2 of Set 13 | wschowa
# Processing Record 3 of Set 13 | general roca
# Processing Record 4 of Set 13 | reconquista
# Processing Record 5 of Set 13 | high level
# Processing Record 6 of Set 13 | marystown
# Processing Record 7 of Set 13 | simbahan
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | la ronge
# Processing Record 10 of Set 13 | barabai
# Processing Record 11 of Set 13 | saint-michel-des-saints
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | kropotkin
# Processing Record 14 of Set 13 | henties bay
# Processing Record 15 of Set 13 | alta floresta
# Processing Record 16 of Set 13 | karratha
# Processing Record 17 of Set 13 | marsa matruh
# Processing Record 18 of Set 13 | de-kastri
# Processing Record 19 of Set 13 | kralendijk
# Processing Record 20 of Set 13 | luan
# Processing Record 21 of Set 13 | krasnozerskoye
# Processing Record 22 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | price
# Processing Record 24 of Set 13 | sayyan
# Processing Record 25 of Set 13 | taltal
# Processing Record 26 of Set 13 | pasighat
# Processing Record 27 of Set 13 | south sioux city
# Processing Record 28 of Set 13 | tura
# Processing Record 29 of Set 13 | thongwa
# Processing Record 30 of Set 13 | kushima
# Processing Record 31 of Set 13 | zyryanka
# Processing Record 32 of Set 13 | sarab
# Processing Record 33 of Set 13 | ashitkovo
# Processing Record 34 of Set 13 | vinh
# Processing Record 35 of Set 13 | oytal
# Processing Record 36 of Set 13 | bam
# Processing Record 37 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 13 | calabozo
# Processing Record 39 of Set 13 | great falls
# Processing Record 40 of Set 13 | khandyga
# Processing Record 41 of Set 13 | shimoda
# Processing Record 42 of Set 13 | smithers
# Processing Record 43 of Set 13 | kulhudhuffushi
# Processing Record 44 of Set 13 | dauphin
# Processing Record 45 of Set 13 | yarkovo
# Processing Record 46 of Set 13 | mahanje
# Processing Record 47 of Set 13 | haradok
# Processing Record 48 of Set 13 | san patricio
# Processing Record 49 of Set 13 | ladnun
# Processing Record 50 of Set 13 | namatanai
# Processing Record 1 of Set 14 | aklavik
# Processing Record 2 of Set 14 | hutchinson
# Processing Record 3 of Set 14 | sahuaripa
# Processing Record 4 of Set 14 | aragats
# Processing Record 5 of Set 14 | manakara
# Processing Record 6 of Set 14 | puerto del rosario
# Processing Record 7 of Set 14 | kitami
# Processing Record 8 of Set 14 | zabaykalsk
# Processing Record 9 of Set 14 | gombe
# Processing Record 10 of Set 14 | vila velha
# Processing Record 11 of Set 14 | moerai
# Processing Record 12 of Set 14 | nipawin
# Processing Record 13 of Set 14 | sirjan
# Processing Record 14 of Set 14 | huercal-overa
# Processing Record 15 of Set 14 | itacarambi
# Processing Record 16 of Set 14 | omboue
# Processing Record 17 of Set 14 | tefe
# Processing Record 18 of Set 14 | tres arroyos
# Processing Record 19 of Set 14 | russkaya polyana
# Processing Record 20 of Set 14 | chapais
# Processing Record 21 of Set 14 | karachi
# Processing Record 22 of Set 14 | lensk
# Processing Record 23 of Set 14 | khandbari
# Processing Record 24 of Set 14 | rio gallegos
# Processing Record 25 of Set 14 | magadan
# Processing Record 26 of Set 14 | quatre cocos
# Processing Record 27 of Set 14 | puerto baquerizo moreno
# Processing Record 28 of Set 14 | macusani
# Processing Record 29 of Set 14 | linkoping
# Processing Record 30 of Set 14 | cayambe
# Processing Record 31 of Set 14 | saldanha
# Processing Record 32 of Set 14 | senneterre
# Processing Record 33 of Set 14 | sovetskiy
# Processing Record 34 of Set 14 | amga
# Processing Record 35 of Set 14 | saint-louis
# Processing Record 36 of Set 14 | alto araguaia
# Processing Record 37 of Set 14 | dicabisagan
# Processing Record 38 of Set 14 | barra do garcas
# Processing Record 39 of Set 14 | deputatskiy
# Processing Record 40 of Set 14 | flin flon
# Processing Record 41 of Set 14 | ekhabi
# Processing Record 42 of Set 14 | chumikan
# Processing Record 43 of Set 14 | komsomolskiy
# Processing Record 44 of Set 14 | zeya
# Processing Record 45 of Set 14 | acari
# Processing Record 46 of Set 14 | mukhen
# Processing Record 47 of Set 14 | verdalsora
# City not found. Skipping...
# Processing Record 48 of Set 14 | sabang
# Processing Record 49 of Set 14 | encamp
# Processing Record 50 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 1 of Set 15 | vao
# Processing Record 2 of Set 15 | ahuimanu
# Processing Record 3 of Set 15 | bhalwal
# Processing Record 4 of Set 15 | rajbiraj
# Processing Record 5 of Set 15 | kemijarvi
# Processing Record 6 of Set 15 | romita
# Processing Record 7 of Set 15 | hanyang
# Processing Record 8 of Set 15 | saint-francois
# Processing Record 9 of Set 15 | paamiut
# Processing Record 10 of Set 15 | mehamn
# Processing Record 11 of Set 15 | pedasi
# Processing Record 12 of Set 15 | arauca
# Processing Record 13 of Set 15 | usinsk
# Processing Record 14 of Set 15 | gunjur
# Processing Record 15 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 15 | rochegda
# Processing Record 17 of Set 15 | baglung
# Processing Record 18 of Set 15 | haverhill
# Processing Record 19 of Set 15 | zheleznodorozhnyy
# Processing Record 20 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 15 | shieli
# Processing Record 22 of Set 15 | muli
# Processing Record 23 of Set 15 | ngunguru
# Processing Record 24 of Set 15 | luba
# Processing Record 25 of Set 15 | honiara
# Processing Record 26 of Set 15 | nikolayevsk-na-amure
# Processing Record 27 of Set 15 | sorkjosen
# Processing Record 28 of Set 15 | ngorongoro
# Processing Record 29 of Set 15 | kyabram
# Processing Record 30 of Set 15 | copala
# Processing Record 31 of Set 15 | farmington
# Processing Record 32 of Set 15 | mrkonjic grad
# Processing Record 33 of Set 15 | salalah
# Processing Record 34 of Set 15 | songjianghe
# Processing Record 35 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 36 of Set 15 | praia
# Processing Record 37 of Set 15 | bolshaya sosnova
# Processing Record 38 of Set 15 | talara
# Processing Record 39 of Set 15 | balsas
# Processing Record 40 of Set 15 | villamontes
# Processing Record 41 of Set 15 | myanaung
# Processing Record 42 of Set 15 | saint-georges
# Processing Record 43 of Set 15 | pak phanang
# Processing Record 44 of Set 15 | verkhnetulomskiy
# Processing Record 45 of Set 15 | tawang
# Processing Record 46 of Set 15 | lufilufi
# Processing Record 47 of Set 15 | innisfail
# Processing Record 48 of Set 15 | dumanjug
# Processing Record 49 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 50 of Set 15 | urucara
# Processing Record 1 of Set 16 | bethanien
# Processing Record 2 of Set 16 | burley
# Processing Record 3 of Set 16 | union
# Processing Record 4 of Set 16 | trabzon
# Processing Record 5 of Set 16 | speightstown
# Processing Record 6 of Set 16 | san quintin
# Processing Record 7 of Set 16 | moissala
# Processing Record 8 of Set 16 | port hardy
# Processing Record 9 of Set 16 | nyurba
# Processing Record 10 of Set 16 | daru
# Processing Record 11 of Set 16 | vozhega
# Processing Record 12 of Set 16 | dubai
# Processing Record 13 of Set 16 | barcelos
# Processing Record 14 of Set 16 | tazovskiy
# Processing Record 15 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 16 | cayenne
# Processing Record 17 of Set 16 | oktyabrskoye
# Processing Record 18 of Set 16 | aswan
# Processing Record 19 of Set 16 | ranong
# Processing Record 20 of Set 16 | turbat
# Processing Record 21 of Set 16 | boende
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari   3.0707  172.7902     81.97        65          17
# 1        Bolgar  54.9500   49.0667     48.54        79         100
# 2     Cape Town -33.9258   18.4232     65.12        50         100
# 3       Qaanaaq  77.4840  -69.3632     29.46        89         100
# 4     Upernavik  72.7868  -56.1549     33.26        97         100
# 5      Skjervoy  70.0311   20.9714     47.75        88         100
# 6       Huarmey -10.0681  -78.1522     64.45        89          52
# 7  Longyearbyen  78.2186   15.6401     28.24        74          75
# 8      Jinchang  38.4953  102.1739     43.68        47           0
# 9        Atuona  -9.8000 -139.0333     78.31        75          13
#
#    Wind Speed Country                 Date Current Description
# 0        8.99      KI  2021-10-11 01:11:28          few clouds
# 1        6.82      RU  2021-10-11 01:11:29     overcast clouds
# 2        4.05      ZA  2021-10-11 01:07:11     overcast clouds
# 3        8.23      GL  2021-10-11 01:11:30     overcast clouds
# 4       12.77      GL  2021-10-11 01:09:09          light snow
# 5        9.93      NO  2021-10-11 01:11:31     overcast clouds
# 6        7.07      PE  2021-10-11 01:11:31       broken clouds
# 7       12.66      SJ  2021-10-11 01:11:35       broken clouds
# 8        2.71      CN  2021-10-11 01:11:35           clear sky
# 9       19.19      PF  2021-10-11 01:11:35          few clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0    Butaritari      KI  2021-10-11 01:11:28   3.0707  172.7902     81.97
# 1        Bolgar      RU  2021-10-11 01:11:29  54.9500   49.0667     48.54
# 2     Cape Town      ZA  2021-10-11 01:07:11 -33.9258   18.4232     65.12
# 3       Qaanaaq      GL  2021-10-11 01:11:30  77.4840  -69.3632     29.46
# 4     Upernavik      GL  2021-10-11 01:09:09  72.7868  -56.1549     33.26
# 5      Skjervoy      NO  2021-10-11 01:11:31  70.0311   20.9714     47.75
# 6       Huarmey      PE  2021-10-11 01:11:31 -10.0681  -78.1522     64.45
# 7  Longyearbyen      SJ  2021-10-11 01:11:35  78.2186   15.6401     28.24
# 8      Jinchang      CN  2021-10-11 01:11:35  38.4953  102.1739     43.68
# 9        Atuona      PF  2021-10-11 01:11:35  -9.8000 -139.0333     78.31
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        65          17        8.99          few clouds
# 1        79         100        6.82     overcast clouds
# 2        50         100        4.05     overcast clouds
# 3        89         100        8.23     overcast clouds
# 4        97         100       12.77          light snow
# 5        88         100        9.93     overcast clouds
# 6        89          52        7.07       broken clouds
# 7        74          75       12.66       broken clouds
# 8        47           0        2.71           clear sky
# 9        75          13       19.19          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
